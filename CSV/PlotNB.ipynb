# %% [markdown]
# ![QGT-collaboration-logo.png](data:image/png;base64,...)
#
# <div class="markdown-google-sans">
#   <h1>This notebook shows visualization of data from QGT database</h1>
# </div>
#
# <a target="_blank" href="https://colab.research.google.com/github/prokudin/PSU_PHYS496/blob/master/database/expdata/PlotNB.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# I pull in as raw data here. Git links must have 'blob' replaced by 'raw'.

# %%
df = pd.read_excel('')

# %%
df

# %% [markdown]
# We bin the data and take a small set of measurements as an example.

# %%
x_bin =
Q_bin =
t_bin =

bin_to_plot = 't ==' +str(t_bin) +'and `Q^2` ==' +str(Q_bin)+ 'and x_B ==' +str(x_bin)

# %%
plot_df = df.query(bin_to_plot)

plot_df

# %% [markdown]
# Here are the resulting plots. The systematic uncertainty columns are placed in the square brackets. The first has the high end uncertainty, then low in second. If high-low uncertainties are averaged, then keep only one np.sqrt in the doublet.

# %%
fig, ax = plt.subplots(figsize = (10, 8), constrained_layout = True)
ax.errorbar(plot_df.phi, plot_df.value,(np.sqrt(plot_df.stat_u**2 + plot_df['']**2), np.sqrt(plot_df.stat_u**2 + plot_df['']**2)), fmt='o', c='k')

#Additional Formatting styles may be included below
